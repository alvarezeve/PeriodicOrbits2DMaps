# %% [markdown]
# ## ModuloA NT

# %%
using PyPlot
using SymPy

# %%
push!(LOAD_PATH,"/home/eve/Documents/Matematicas/Proyectos/Implementacion")
# Out:
# 4-element Array{String,1}:
#  "@"
#  "@v#.#"
#  "@stdlib"
#  "/home/eve/Documents/Matematicas/Proyectos/Implementacion"

# %%
using PeriodicosSymmetries

# %% [markdown]
# 🔵 Definimos el mapeo

# %%
function MapeoX(v)
    x = v[1]
    y = v[2]
    vx = x+0.3*(1-(y-0.1*sin(2*pi*x))^2)
    vy = y-0.1*sin(2*pi*x)
    return [vx,vy]
end
# Out:
# MapeoX (generic function with 1 method)

# %% [markdown]
# 🔵 Definimos las simetrias con la que trabajaremos. La primera de ellas debe ser una funcion que regrese un Array1 mientras la segunda una funcion que regrese un Float.
#
# Buscamos puntos que empiezen en la simetria 1 y que despues de algunas iteraciones(2n,22n+1,2n-1) esten en la simetria 3.

# %% [markdown]
# Usando el conjunto invariante
# $$I_{0}= \{(x,y)| x=0\}$$
# $$I_{1} = \{(x,y)| x=1/2\}$$
# usando la condicion del primer conjunto invariante
# $$I_{2}=\{x | x =\frac{a}{2}(1-y^{2})\}$$
# $$I_{3}=\{x | x =\frac{a}{2}(1-y^{2})+1/2\}$$

# %%
a=0.3
b=0.1
# Out:
# 0.1

# %%
simetria1v(x,y) = [0,y]
simetria2v(x,y) = [1/2,y]
simetria3v(x,y) = [a*(1-y^2)/2.0, y]
simetria4v(x,y) = [a*(1-y^2)/2.0+0.5 , y]
# Out:
# simetria4v (generic function with 1 method)

# %%
simetria1f(x,y) = x
simetria2f(x,y) = x-0.5
simetria3f(x,y) = x-a*(1-y^2)/2.
simetria4f(x,y) = x-a*(1-(y^2))/2. + 0.5
# Out:
# simetria4f (generic function with 1 method)

# %%
pp1 = periodicosN(MapeoX,simetria1v,simetria2f,2,0.3)
# Out:
# 2-element Array{Float64,1}:
#  0.0
#  0.455047794920231

# %% [markdown]
# 🔵 Para verificar si son de periodo 4 le preguntamos a la funcion:

# %%
Buscaperiodo(pp1,MapeoX,1,1e-10)
# Out:
# periodo =
# 4.0

# %%
vv = iterar(MapeoX,pp1,15,1);

# %%
listasim1Y = [y for y in -2:0.1:2.0] 
listasim1X = [0.0 for y in listasim1Y]
listasim2X = [1/2 for y in listasim1Y]
listasim3X = [mod(a*(1-y^2)/2,1) for y in listasim1Y]
listasim4X = [mod(a*(1-y^2)/2.0+0.5,1) for y in listasim1Y];

# %%
scatter(vv[1],vv[2])
plot(listasim1X, listasim1Y, label = "")
plot(listasim3X, listasim1Y, label = "")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fcc3baa6410>

# %%
pp3 = periodicosN(MapeoX,simetria1v,simetria4f,3,0.3)
pp4 = periodicosN(MapeoX,simetria1v,simetria4f,4,0.7)
pp5 = periodicosN(MapeoX,simetria1v,simetria4f,5,0.2)
pp6 = periodicosN(MapeoX,simetria1v,simetria4f,6,0.9)
# Out:
# 2-element Array{Float64,1}:
#  0.0
#  1.0397553702579916

# %%
print(Buscaperiodo(pp3,MapeoX,1,1e-10))
print("\n")
print(Buscaperiodo(pp4,MapeoX,1,1e-10))
print("\n")
print(Buscaperiodo(pp5,MapeoX,1,1e-10))
print("\n")
print(Buscaperiodo(pp6,MapeoX,1,1e-10))
# Out:
# periodo = 5.0
# periodo = 7.0
# periodo = 9.0
# periodo = 11.0

# %%
vv3 = iterar(MapeoX,pp3,15,1);
vv4 = iterar(MapeoX,pp4,15,1);
vv5 = iterar(MapeoX,pp5,15,1);
vv6 = iterar(MapeoX,pp6,15,1);

# %%
scatter(vv[1],vv[2])
scatter(vv3[1],vv3[2])
scatter(vv4[1],vv4[2])
scatter(vv5[1],vv5[2])
scatter(vv6[1],vv6[2])
plot(listasim1X, listasim1Y, label = "")
plot(listasim3X, listasim1Y, label = "")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fcc3b9d9b50>

# %%
pp3n = periodicosN(MapeoX,simetria1v,simetria4f,55,-0.3)
pp4n = periodicosN(MapeoX,simetria1v,simetria4f,26,-0.7)
pp5n = periodicosN(MapeoX,simetria1v,simetria4f,46,-0.2)
pp6n = periodicosN(MapeoX,simetria1v,simetria4f,45,-0.9)
# Out:
# 2-element Array{Float64,1}:
#   0.0
#  -1.2977416405482436

# %%
#que son estos?
# pp3n = [pp3[1],-pp3[2]]
# pp4n = [pp4[1],-pp4[2]]
# pp5n = [pp5[1],-pp5[2]]
# pp6n = [pp6[1],-pp6[2]]

# %%
vv3n = iterar(MapeoX,pp3n,500,1);
vv4n = iterar(MapeoX,pp4n,60,1);
vv5n = iterar(MapeoX,pp5n,93,1);
vv6n = iterar(MapeoX,pp6n,92,1);

# %%
listasim1YA = [y for y in -1:0.1:1.0] 
listasim1YB = [y for y in -2.5:0.1:-1.1] 
listasim1YC = [y for y in 1.1:0.1:2.5] 
listasim2XA = [1/2 for y in listasim1YA];
listasim3XA = [mod(a*(1-y^2)/2,1) for y in listasim1YA];
listasim3XB = [mod(a*(1-y^2)/2,1) for y in listasim1YB];
listasim3XC = [mod(a*(1-y^2)/2,1) for y in listasim1YC];

# %%
# scatter(vv[1],vv[2])
# scatter(vv3[1],vv3[2])
# scatter(vv4[1],vv4[2])
# scatter(vv5[1],vv5[2])
# scatter(vv6[1],vv6[2])
scatter(vv3n[1],vv3n[2])
scatter(vv4n[1],vv4n[2])
scatter(vv5n[1],vv5n[2])
scatter(vv6n[1],vv6n[2])
plot(listasim1X, listasim1Y, label = "")
plot(listasim3XA, listasim1YA, label = "", color = "orange")
plot(listasim3XB, listasim1YB, label = "", color = "orange")
plot(listasim3XC, listasim1YC, label = "", color = "orange")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fcc3b979050>

# %%
print(Buscaperiodo(pp3n,MapeoX,1,1e-2))
print("\n")
print(Buscaperiodo(pp4n,MapeoX,1,1e-2))
print("\n")
print(Buscaperiodo(pp5n,MapeoX,1,1e-3))
print("\n")
print(Buscaperiodo(pp6n,MapeoX,1,1e-3))
# Out:
# periodo = 497.0
# periodo = 1.0
# periodo = 91.0
# periodo = 89.0

# %% [markdown]
# 🔵 Busquemos en las otras simetrias.

# %%
pb2 = periodicosN(MapeoX,simetria2v,simetria4f,2,0.3)
pb3 = periodicosN(MapeoX,simetria2v,simetria4f,3,0.7)
pb4 = periodicosN(MapeoX,simetria2v,simetria4f,4,0.2)
pb5 = periodicosN(MapeoX,simetria2v,simetria4f,5,0.9)
# Out:
# 2-element Array{Float64,1}:
#  0.5
#  1.3769327659865538

# %%
print(Buscaperiodo(pb2,MapeoX,1,1e-4))
print("\n")
print(Buscaperiodo(pb3,MapeoX,1,1e-4))
print("\n")
print(Buscaperiodo(pb4,MapeoX,1,1e-4))
print("\n")
print(Buscaperiodo(pb5,MapeoX,1,1e-4))
# Out:
# periodo = 3.0
# periodo = 5.0
# periodo = 7.0
# periodo = 9.0

# %%
vb2 = iterar(MapeoX,pb2,10,1);
vb3 = iterar(MapeoX,pb3,10,1);
vb4 = iterar(MapeoX,pb4,10,1);
vb5 = iterar(MapeoX,pb5,10,1);

# %%
scatter(vb2[1],vb2[2])
scatter(vb3[1],vb3[2])
scatter(vb4[1],vb4[2])
scatter(vb5[1],vb5[2])
plot(listasim1X, listasim1Y, label = "")
plot(listasim2X, listasim1Y, label = "")
# plot(listasim3XA, listasim1YA, label = "", color = "orange")
# plot(listasim3XB, listasim1YB, label = "", color = "orange")
# plot(listasim3XC, listasim1YC, label = "", color = "orange")
plot(listasim4X, listasim1Y, label = "", color = "orange")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fcc3b8f02d0>

# %% [markdown]
# 🔵 Mas simetrias.

# %%
puntosPS3 = []
for i in 2:7
    x = periodicosN(MapeoX,simetria3v,simetria1f,i,0.5)
    append!(puntosPS3,[x])
end

# %%
for i in 2:length(puntosPS3)
    print(Buscaperiodo(puntosPS3[i],MapeoX,1,1e-5))
    print("\n")
end
# Out:
# periodo = 1.0
# periodo = 1.0
# periodo = 1.0
# periodo = 1.0
# periodo = 1.0

# %% [markdown]
# 🌟 Otro...

# %%
puntosPS4 = []
for i in 2:10
    x = periodicosN(MapeoX,simetria4v,simetria1f,i,0.5)
    append!(puntosPS4,[x])
end

# %%
for i in 2:length(puntosPS4)
    print(Buscaperiodo(puntosPS4[i],MapeoX,1,1e-5))
    print("\n")
end
# Out:
# periodo = 7.0
# periodo = 9.0
# periodo = 11.0
# periodo = 13.0
# periodo = 15.0
# periodo = 17.0
# periodo = 19.0
# periodo = 21.0

# %%
listaS4 = []
for i in 2:length(puntosPS4)
    x =  iterar(MapeoX,puntosPS4[i],2*i +2,1)
    append!(listaS4,[x])
end

# %%
for i in 1:length(listaS4)
    scatter(listaS4[i][1],listaS4[i][2])
end



plot(listasim1X, listasim1Y, label = "")
plot(listasim2X, listasim1Y, label = "")
plot(listasim4X, listasim1Y, label = "", color = "orange")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fcc3b92f8d0>

# %% [markdown]
# 🌟 La ultima

# %%
puntosPS4B = []
for i in 2:10
    x = periodicosN(MapeoX,simetria4v,simetria2f,i,0.5)
    append!(puntosPS4B,[x])
end

# %%
for i in 2:length(puntosPS4B)
    print(Buscaperiodo(puntosPS4B[i],MapeoX,1,1e-5))
    print("\n")
end
# Out:
# periodo = 1.0
# periodo = 1.0
# periodo = 11.0
# periodo = 13.0
# periodo = 15.0
# periodo = 17.0
# periodo = 19.0
# periodo = 21.0

# %%
listaS4B = []
for i in 2:length(puntosPS4B)
    x =  iterar(MapeoX,puntosPS4B[i],2*i +2,1)
    append!(listaS4B,[x])
end

# %%
for i in 1:length(listaS4B)
    scatter(listaS4B[i][1],listaS4B[i][2])
end
plot(listasim2X, listasim1Y, label = "")
plot(listasim4X, listasim1Y, label = "", color = "orange")
xlim(0,1)
ylim(0.6,1.5)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# (0.6, 1.5)

# %%
for i in 1:length(listaS4B)
    scatter(listaS4B[i][1],listaS4B[i][2])
end
for i in 1:length(listaS4)
    scatter(listaS4[i][1],listaS4[i][2])
end

scatter(vv3n[1],vv3n[2])
scatter(vv4n[1],vv4n[2])
scatter(vv5n[1],vv5n[2])
scatter(vv6n[1],vv6n[2])
plot(listasim1X, listasim1Y, label = "")
plot(listasim3XA, listasim1YA, label = "", color = "orange")
plot(listasim3XB, listasim1YB, label = "", color = "orange")
plot(listasim3XC, listasim1YC, label = "", color = "orange")

plot(listasim1X, listasim1Y, label = "")
plot(listasim2X, listasim1Y, label = "")
plot(listasim4X, listasim1Y, label = "", color = "orange")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fcc3b740910>

# %%
function IterarMap(f, x_ini, n)   #Definimos una función para iterar el mapeo

    x = x_ini[1]                      #                                     #Damos condiciones iniciales
    y = x_ini[2]                          #

    iteradosMapX = [x]
    iteradosMapY = [y]               #Definimos dos listas que tendran los valores de cada par ordenado de theta y P, y agregamos las condiciones iniciales

    for i=0:n              #iniciamos un ciclo de iteraciones donde se calculan x_n, y_n y se agregan a lalista correspodiente
        F = f(x,y)

        push!(iteradosMapX,mod(F[1],1))
        push!(iteradosMapY,F[2])

        #x_ini = [F[1],F[2]]
        
       x = F[1]
       y = F[2]

    end

    return iteradosMapX, iteradosMapY  #La funcion iterados regresa las listas que corresponden a la trayectoria del

end

function GraficarMap(f)
    n = 50
    #s=2*pi/14.
    s = 1/20.
    i=0.
    for p_i=0:s:1
        for x_i =-1:s:1
            i=i+1
            x_ini=[p_i,x_i]
            a,b = IterarMap(f,x_ini,n)
            p = scatter(a,b,marker=".",s=0.1,color="gray")
            
        end
    end

end
# Out:
# GraficarMap (generic function with 1 method)

# %%
function cuadraticM(x::Any,y::Any,a,b)
    vx = x+a*(1-(y-b*sin(2*pi*x))^2)
    vy = y-b*sin(2*pi*x)
    return [vx,vy]
end
# Out:
# cuadraticM (generic function with 1 method)

# %%
mapeoca(x,y)=cuadraticM(x,y,0.3,0.1)
# Out:
# mapeoca (generic function with 1 method)

# %%
GraficarMap(mapeoca)
for i in 1:length(listaS4B)
    scatter(listaS4B[i][1],listaS4B[i][2])
end
for i in 1:length(listaS4)
    scatter(listaS4[i][1],listaS4[i][2])
end

scatter(vv3n[1],vv3n[2])
scatter(vv4n[1],vv4n[2])
scatter(vv5n[1],vv5n[2])
scatter(vv6n[1],vv6n[2])
plot(listasim1X, listasim1Y, label = "")
plot(listasim3XA, listasim1YA, label = "", color = "orange")
plot(listasim3XB, listasim1YB, label = "", color = "orange")
plot(listasim3XC, listasim1YC, label = "", color = "orange")

plot(listasim1X, listasim1Y, label = "")
plot(listasim2X, listasim1Y, label = "")
plot(listasim4X, listasim1Y, label = "", color = "orange")
ylim(-1.5,1.5)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# (-1.5, 1.5)

# %%
pc2 = periodicosN(MapeoX,simetria2v,simetria1f,4,-0.1)
# Out:
# 2-element Array{Float64,1}:
#   0.5
#  -1.0957943910577401

# %%
Buscaperiodo(pc2,MapeoX,1,1e-5)
# Out:
# periodo =
# 8.0

# %%
vc2 = iterar(MapeoX,pc2,15,1);

# %%
listasim1Y = [y for y in -2:0.1:2.0] 
listasim1X = [0.0 for y in listasim1Y]
listasim2X = [1/2 for y in listasim1Y]
listasim3X = [mod(a*(1-y^2)/2,1) for y in listasim1Y]
listasim4X = [mod(a*(1-y^2)/2.0+0.5,1) for y in listasim1Y];

# %%
scatter(vc2[1],vc2[2])
plot(listasim1X, listasim1Y, label = "")
plot(listasim3X, listasim1Y, label = "")
plot(listasim2X, listasim1Y, label = "")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fcc2a8b8450>

# %%
mapeo8(v) = composition(MapeoX,8)(v)
# Out:
# mapeo8 (generic function with 1 method)

# %%
using ForwardDiff

# %%
mpc2 = ForwardDiff.jacobian(x ->mapeo8([x[1],x[2]]), pc2)
# Out:
# 2×2 Array{Float64,2}:
#   1.49916   1.93252
#  -0.296431  0.28492

# %%
using LinearAlgebra

# %%
eigenvc2 = eigen(mpc2)
# Out:
# Eigen{Complex{Float64},Complex{Float64},Array{Complex{Float64},2},Array{Complex{Float64},1}}
# values:
# 2-element Array{Complex{Float64},1}:
#  0.8920393450755375 - 0.4519577489513864im
#  0.8920393450755375 + 0.4519577489513864im
# vectors:
# 2×2 Array{Complex{Float64},2}:
#   0.931133-0.0im        0.931133+0.0im
#  -0.292524-0.217764im  -0.292524+0.217764im
